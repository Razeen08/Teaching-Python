# %% [markdown]
# # Practice Notebook for Numpy
# * Look at the attached code snippets and type by yourself.
# * Note points where you don't understand.
# * Tweak codes for better understanding, identify the parameters that you can control and observe their effect.
# * You may ask ChatGPT for explanation.

# %% [markdown]
# # Note any troubles you face or any questions you come up with, we will have a discussion session just on this practice notebook.

# %% [markdown]
# # Set Environment

# %%
import numpy as np

# %% [markdown]
# ![image.png](attachment:443958a8-f1af-4f85-97df-e6e3efe04203.png)

# %% [markdown]
# ![image.png](attachment:e6fd4b63-8ace-4952-8b41-9fe8f898c1e0.png)

# %% [markdown]
# ![image.png](attachment:a1398847-c76f-4e36-81c4-7fcac61d5c1c.png)

# %% [markdown]
# ![image.png](attachment:f289bc31-bc40-45e3-97f6-bca4cfe0123b.png)

# %% [markdown]
# ![image.png](attachment:0facbfba-d4e0-4b4a-ba91-0fe26fd91ebc.png)

# %% [markdown]
# ![image.png](attachment:2ca15150-e704-4f5f-aa56-8d308816b789.png)

# %% [markdown]
# ![image.png](attachment:b13adc96-00ac-42e3-926a-23685a54459b.png)

# %% [markdown]
# ![image.png](attachment:2fcc7cc7-1d4f-4fbd-9f50-523d28a3a1a4.png)

# %% [markdown]
# ![image.png](attachment:fc81d22c-da99-4aaf-9f24-6f718d0cb47e.png)

# %% [markdown]
# ![image.png](attachment:0fd89c1f-d6be-4e96-b544-c71e78c1e290.png)

# %% [markdown]
# **You can download the output text files from Output > /kaggle/working directory**

# %% [markdown]
# ![image.png](attachment:040cf04f-f759-46df-8bd8-b90c7c1e9691.png)

# %% [markdown]
# **Report to me if it does not work!**

# %% [markdown]
# # Solve this system of linear equations
# ![image.png](attachment:439e1730-b6b1-4ad3-91b8-98eec51c8dc4.png)
